# %% [markdown]
# # header ada
# ## Sub-header
# ### sub-sub header
#
# $ y = 2x+1$
#
# Library untuk menghilangkan warning
# ```py
# import warnings
# warnings.filterwarnings('ignore')
# ```
#
# *library*
# **bold**
# ***bolditalic***
#
# ![image.png](attachment:image.png)
#
# bsd_006 nih boss:
# - yudis
# - adit
# 1. ada
# 2. yyy:
#     - Salman
#     - Haykal

# %% [markdown]
# ---

# %% [markdown]
# `conda --version`
